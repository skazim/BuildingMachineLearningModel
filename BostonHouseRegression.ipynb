# %%
from sklearn.datasets import load_boston
import numpy as np
boston= load_boston()

x = boston.data[:,5]
x = np.array([[v] for v in x])

y= boston.target
slope= np.linalg.lstsq(x,y,rcond=None)[0]
print("Slope of the Line",slope)
# Out:
# Slope of the Line [3.6533504]
